# %%
# %load scripts/document_status.py
import sys
import os
import re
import pandas as pd
import redis
from pathlib import Path
sys.path.append('/home/jeremy/Library')

from storage.cherrytree import CherryTree

r = redis.Redis(decode_responses=True)
project_index_key = 'projects:filepath.document:index'

def get_document_metadata(node):
    filepath = Path(node.filepath).resolve()
    document_key = r.hget(project_index_key, str(filepath))
    if not document_key:
        return None
    document_data_key = r.hget(document_key, 'metadata')
    if not document_data_key:
        return None
    data = {k:v for k,v in r.hgetall(document_data_key).items()}
    if not data:
        return None
    return dict(node=node, data=data)

# %%
ct = CherryTree('synopsis.ctd')
df = pd.DataFrame(filter(None, [get_document_metadata(n) for n in ct.nodes('Stories') if n.filepath]))
df['name'] = df.node.apply(lambda x: x.name)
df['status'] = df.data.apply(lambda x: x.get('status'))

# %%
df.head()
# Out:
#                                                 node  \
# 0  <storage.cherrytree.Node object at 0x7f1fc56cd...
# 1  <storage.cherrytree.Node object at 0x7f1fc56cd...
# 2  <storage.cherrytree.Node object at 0x7f1fc56cd...
# 3  <storage.cherrytree.Node object at 0x7f1fc56d4...
# 4  <storage.cherrytree.Node object at 0x7f1fc56d4...
#
#                                                 data                  name  \
# 0  {'title': 'Lunch with Julia', 'identifier': '7...      Lunch With Julia
# 1  {'date': 'October 1988', 'project': 'omaf', 't...  Julia Rides a Harley
# 2  {'status': 'Final', 'date': 'October 1988', 'l...             Bule Kaya
# 3  {'status': 'Uncertain', 'date': 'October 1988'...  Julia at the Tanamur
# 4  {'location': 'Borobudur', 'status': 'Rewrite',...        Date With Eric
#
#       status
# 0      Final
# 1      Final
# 2      Final
# 3  Uncertain
# 4    Rewrite

# %%
df[~df.status.str.contains('Final|Hold')][['name', 'status']]
# Out:
#                                         name              status
# 4                             Date With Eric             Rewrite
# 6                          Julia Finds Photo              Expand
# 12                         Syd Warns Cameron   Rewrite and place
# 15                       Syd Reveals History    Expand and place
# 16                              Useful Idiot   Rewrite and place
# 17                        Unequal Friendship              Expand
# 18                             Sabam Furious              Expand
# 19                                  Syd Dies              Expand
# 20                       Victor Learns Truth              Expand
# 21                       Sabam Fires Cameron              Expand
# 22                      Cameron Says Goodbye             Rewrite
# 33                       Spoor takes command              Expand
# 34                       Spoor Hears Reports              Expand
# 35                        Feeding the troops             Rewrite
# 36              Ining Is Training Guerrillas              Expand
# 37        Thai Authorities Released Freeberg              Expand
# 40                            Major Criminal              Expand
# 41                           Appeal to Foote    Expand and place
# 42                 Spoor Orders Night Patrol              Expand
# 43                            Spoor poisoned              Expand
# 44                       Father Interrogates              Expand
# 45                               Ani engaged              Expand
# 46                             Shopping List              Expand
# 47                           Ani Serves Rice              Expand
# 48                       Ani Berates Muharto              Expand
# 50                           Muharto Marries              Expand
# 51                    Ani Berates Westerling              Expand
# 53                   Crushing Disappointment             Rewrite
# 61                    Bambang Decides To Fly              Expand
# 64                         Assigned to Spoor              Expand
# 67                    Assigned to Westerling              Expand
# 68                           Victor Defects.              Expand
# 70                         Cobley Makes Deal              Expand
# 72                              POAS Flights              Expand
# 73                       Cobley Flies Cadres              Expand
# 74   Suryadarma Takes Fowlers Fuel Allowance              Expand
# 77                               Bob Arrives              Expand
# 78                               SE Airlines              Expand
# 80                         Buying the Dakota              Expand
# 82                            Missing Dakota              Expand
# 83                             Beach Landing              Expand
# 84                             First Mission              Expand
# 85                        Bob Meets Soekarno              Fix Up
# 86                     Bob Walters Complains              Expand
# 91                          Bob Bought Suits              Expand
# 92                         Deportation Offer      Think about it
# 94                             Black Flights              Expand
# 95           Bob Requests Muharto Reassigned              Expand
# 97                             Soekarno tour              Fix up
# 98                     Bob Defies Suryadarma              Expand
# 99                               Bob Returns              Expand
# 100          Suryadarma Takes Fuel Allowance              Expand
# 101                    Ri-002 Drops Leaflets              Expand
# 103                                 Gold Run              Expand
# 112                             Quinine Case              Expand
# 115                        Money for Nothing  Rewrite and expand
# 119                         Muharto Appalled              Expand
# 123                Reconciling With Muharto.              Expand
# 125                             Bob Vanishes              Expand

# %%
loadpy scripts/match_stories_and_files
